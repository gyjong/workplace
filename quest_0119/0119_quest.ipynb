# %%
import pandas as pd
pd.read_csv('/Users/kenny_jung/aiffel/data/titanic.csv')
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data = pd.read_csv('/Users/kenny_jung/aiffel/data/titanic.csv')
data.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
data.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  879.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.679181    0.525424    0.377401    0.377401
# std      0.836069   13.559664    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
data.drop('Name', axis=1)
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
data
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data.drop(['Name', 'Ticket', 'ticket_date'], axis=1)
# Out:
#      Pclass   Gendr   Age  SibSp  Parch Embarked  Survived
# 0         3    male  22.0      1      0        S         0
# 1         1  female  38.0      1      0        C         1
# 2         3  female  26.0      0      0        S         1
# 3         1  female   NaN      1      0        S         1
# 4         3    male  35.0      0      0        S         0
# ..      ...     ...   ...    ...    ...      ...       ...
# 880       2    male  27.0      0      0        S         0
# 881       1  female  19.0      0      0        S         1
# 882       3  female  28.0      1      2        S         0
# 883       1    male  26.0      0      0        C         1
# 884       3    male  32.0      0      0        Q         0
#
# [885 rows x 7 columns]

# %%
dt_data = data.drop(['Name', 'Ticket', 'ticket_date'], axis=1)
dt_data
# Out:
#      Pclass   Gendr   Age  SibSp  Parch Embarked  Survived
# 0         3    male  22.0      1      0        S         0
# 1         1  female  38.0      1      0        C         1
# 2         3  female  26.0      0      0        S         1
# 3         1  female   NaN      1      0        S         1
# 4         3    male  35.0      0      0        S         0
# ..      ...     ...   ...    ...    ...      ...       ...
# 880       2    male  27.0      0      0        S         0
# 881       1  female  19.0      0      0        S         1
# 882       3  female  28.0      1      2        S         0
# 883       1    male  26.0      0      0        C         1
# 884       3    male  32.0      0      0        Q         0
#
# [885 rows x 7 columns]

# %%
dt_data.iloc[884]
# Out:
# Pclass         3
# Gendr       male
# Age         32.0
# SibSp          0
# Parch          0
# Embarked       Q
# Survived       0
# Name: 884, dtype: object

# %%
data.isna().sum()
# Out:
# Pclass         0
# Name           0
# Gendr          0
# Age            6
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       2
# Survived       0
# ticket_date    0
# dtype: int64

# %%
dt_data.isna().sum()
# Out:
# Pclass      0
# Gendr       0
# Age         6
# SibSp       0
# Parch       0
# Embarked    2
# Survived    0
# dtype: int64

# %% [markdown]
# ## Missing Values

# %%
data[data['Embarked'].isna()]
# Out:
#      Pclass                              Name   Gendr   Age  SibSp  Parch  \
# 15        2  Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 322       3          Sage, Mr. George John Jr    male  28.0      8      2
#
#        Ticket Embarked  Survived ticket_date
# 15     248706      NaN         1  1912-03-05
# 322  CA. 2343      NaN         0  1912-03-26

# %%
data[data['Embarked'].isna()].index
# Out:
# Index([15, 322], dtype='int64')

# %%
len(data)
# Out:
# 885

# %%
data.dropna()
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male  28.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data.dropna(subset=['Embarked'])
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data['Age'].fillna(40)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      40.0
# 4      35.0
#        ...
# 880    27.0
# 881    19.0
# 882    28.0
# 883    26.0
# 884    32.0
# Name: Age, Length: 885, dtype: float64

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())
data
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  28.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data.isna().sum()
# Out:
# Pclass         0
# Name           0
# Gendr          0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       2
# Survived       0
# ticket_date    0
# dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    640
# C    166
# Q     77
# Name: count, dtype: int64

# %%
data['Embarked'] = data['Embarked'].fillna('S')
data.isna().sum()
# Out:
# Pclass         0
# Name           0
# Gendr          0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       0
# Survived       0
# ticket_date    0
# dtype: int64

# %% [markdown]
# ## Outliers

# %%
data.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  885.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.667797    0.525424    0.377401    0.377401
# std      0.836069   13.514272    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
data['Age'].sort_values(ascending=False)
# Out:
# 321    145.0
# 279     97.0
# 627     80.0
# 845     74.0
# 95      71.0
#        ...
# 379      1.0
# 823      1.0
# 384      1.0
# 171      1.0
# 163      1.0
# Name: Age, Length: 885, dtype: float64

# %%
data['SibSp'].sort_values().tail(15)
# Out:
# 809    4
# 51     4
# 820    4
# 680    5
# 71     5
# 384    5
# 60     5
# 477    5
# 857    8
# 158    8
# 840    8
# 179    8
# 322    8
# 789    8
# 200    8
# Name: SibSp, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data['SibSp'])
# Out:
# /var/folders/b9/d_8nll_s47g6w2x0spndwwl80000gn/T/ipykernel_19003/2683520910.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SibSp'])
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.displot(data['Age'])

# %%
sns.scatterplot( x = data.index, y = data['SibSp'])
# Out:
# <Axes: xlabel='None', ylabel='SibSp'>

# %%
sns.scatterplot(x = data.index, y = data['Age'])
# Out:
# <Axes: xlabel='None', ylabel='Age'>

# %%
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>
